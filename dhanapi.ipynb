# %%
client_id = 1100915906
access_token = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJpc3MiOiJkaGFuIiwicGFydG5lcklkIjoiIiwiZXhwIjoxNjkwMzEyODM4LCJ0b2tlbkNvbnN1bWVyVHlwZSI6IlNFTEYiLCJ3ZWJob29rVXJsIjoiIiwiZGhhbkNsaWVudElkIjoiMTEwMDkxNTkwNiJ9.0k0tb0qPq7WhJ5cZgB7VuRWfisg85n-IQoj7KzRMO5h9P2RCa62766vA-hBwLuLcX9J2jfaIHAcHVtrL2w0UaA"

# %%
from dhanhq  import dhanhq
dhan = dhanhq("client_id",access_token)
dhan.get_positions()
# Out:
# {'status': 'success', 'remarks': '', 'data': []}

# %%
# Get fund limits
asam = dhan.get_fund_limits()["data"]

# %%
print(asam.get('availabelBalance'))
# Out:
# 1325.16

# %%
dhan.get_order_list()["data"]
# Out:
# []

# %%
dhan.intraday_daily_minute_charts(
    security_id='11536',
    exchange_segment='NSE_EQ',
    instrument_type='EQUITY'
)
# Out:
# {'status': 'success',
#  'remarks': '',
#  'data': {'open': [3208.0,
#    3202.2,
#    3201.75,
#    3202.55,
#    3202.0,
#    3202.8,
#    3200.4,
#    3199.2,
#    3198.4,
#    3200.0,
#    3199.0,
#    3198.45,
#    3199.95,
#    3198.0,
#    3197.0,
#    3196.2,
#    3195.0,
#    3194.9,
#    3194.3,
#    3195.0,
#    3194.95,
#    3195.0,
#    3196.15,
#    3196.1,
#    3197.5,
#    3196.9,
#    3197.2,
#    3196.15,
#    3197.4,
#    3197.95,
#    3195.15,
#    3196.3,
#    3196.7,
#    3197.35,
#    3197.3,
#    3199.95,
#    3201.5,
#    3203.0,
#    3203.35,
#    3202.5,
#    3204.0,
#    3202.6,
#    3201.85,
#    3200.5,
#    3200.9,
#    3200.5,
#    3199.0,
#    3198.45,
#    3198.05,
#    3198.3,
#    3199.1,
#    3196.2,
#    3196.8,
#    3196.6,
#    3196.2,
#    3195.1,
#    3195.65,
#    3199.2,
#    3198.7,
#    3198.75,
#    3198.1,
#    3197.95,
#    3198.2,
#    3199.0,
#    3199.0,
#    3198.9,
#    3198.75,
#    3199.95,
#    3200.0,
#    3198.9,
# ...

# %%
from pandas import pandas as pd

# %%
df = pd.read_csv('api-scrip-master.csv')

# %%
df[(df.SEM_EXM_EXCH_ID == "NSE") & (df.SEM_TRADING_SYMBOL == "FINNIFTY-Jun2023-18550-CE")]
# Out:
#       SEM_EXM_EXCH_ID  SEM_SEGMENT  SEM_SMST_SECURITY_ID SEM_INSTRUMENT_NAME  \
# 90172             NSE            D                 40023              OPTIDX
#
#        SEM_EXPIRY_CODE         SEM_TRADING_SYMBOL  SEM_LOT_UNITS  \
# 90172                0  FINNIFTY-Jun2023-18550-CE           40.0
#
#                 SEM_CUSTOM_SYMBOL      SEM_EXPIRY_DATE  SEM_STRIKE_PRICE  \
# 90172  FINNIFTY 27 JUN 18550 CALL  2023-06-27 14:30:00           18550.0
#
#       SEM_OPTION_TYPE  SEM_TICK_SIZE SEM_EXPIRY_FLAG
# 90172              CE            5.0               M

# %%
df.keys()
# Out:
# Index(['SEM_EXM_EXCH_ID', ' SEM_SEGMENT', 'SEM_SMST_SECURITY_ID',
#        'SEM_INSTRUMENT_NAME', 'SEM_EXPIRY_CODE', 'SEM_TRADING_SYMBOL',
#        'SEM_LOT_UNITS', 'SEM_CUSTOM_SYMBOL', 'SEM_EXPIRY_DATE',
#        'SEM_STRIKE_PRICE', 'SEM_OPTION_TYPE', 'SEM_TICK_SIZE',
#        'SEM_EXPIRY_FLAG'],
#       dtype='object')

# %%
allsymbols = df.SEM_TRADING_SYMBOL

# %%
allsy = allsymbols.str.contains('18500')

# %%
allstrikes = df.SEM_STRIKE_PRICE
allstrikes
# Out:
# 0        -0.01
# 1        -0.01
# 2        -0.01
# 3        -0.01
# 4        -0.01
#           ...
# 150252    7.00
# 150253     NaN
# 150254     NaN
# 150255     NaN
# 150256     NaN
# Name: SEM_STRIKE_PRICE, Length: 150257, dtype: float64

# %%
df.columns
# Out:
# Index(['SEM_EXM_EXCH_ID', ' SEM_SEGMENT', 'SEM_SMST_SECURITY_ID',
#        'SEM_INSTRUMENT_NAME', 'SEM_EXPIRY_CODE', 'SEM_TRADING_SYMBOL',
#        'SEM_LOT_UNITS', 'SEM_CUSTOM_SYMBOL', 'SEM_EXPIRY_DATE',
#        'SEM_STRIKE_PRICE', 'SEM_OPTION_TYPE', 'SEM_TICK_SIZE',
#        'SEM_EXPIRY_FLAG'],
#       dtype='object')

# %%
df.SEM_EXPIRY_DATE
# Out:
# 0         2099-03-26 00:00:00
# 1         2099-03-26 00:00:00
# 2         2099-03-26 00:00:00
# 3         2099-03-26 00:00:00
# 4         2099-03-26 00:00:00
#                  ...
# 150252                    NaN
# 150253                    NaN
# 150254                    NaN
# 150255                    NaN
# 150256                    NaN
# Name: SEM_EXPIRY_DATE, Length: 150257, dtype: object

# %%
strikeprice = "18550"
df[df['SEM_TRADING_SYMBOL'].str.contains(strikeprice) & df['SEM_INSTRUMENT_NAME'].str.contains("OPTIDX") & df['SEM_EXPIRY_DATE'].str.contains("2023-06")]
# Out:
#        SEM_EXM_EXCH_ID  SEM_SEGMENT  SEM_SMST_SECURITY_ID SEM_INSTRUMENT_NAME  \
# 90172              NSE            D                 40023              OPTIDX
# 90173              NSE            D                 40024              OPTIDX
# 109920             NSE            D                 60227              OPTIDX
# 109921             NSE            D                 60228              OPTIDX
#
#         SEM_EXPIRY_CODE         SEM_TRADING_SYMBOL  SEM_LOT_UNITS  \
# 90172                 0  FINNIFTY-Jun2023-18550-CE           40.0
# 90173                 0  FINNIFTY-Jun2023-18550-PE           40.0
# 109920                0     NIFTY-Jun2023-18550-CE           50.0
# 109921                0     NIFTY-Jun2023-18550-PE           50.0
#
#                  SEM_CUSTOM_SYMBOL      SEM_EXPIRY_DATE  SEM_STRIKE_PRICE  \
# 90172   FINNIFTY 27 JUN 18550 CALL  2023-06-27 14:30:00           18550.0
# 90173    FINNIFTY 27 JUN 18550 PUT  2023-06-27 14:30:00           18550.0
# ...

# %%
strikeprice = "18550"
indice = "FINNIFTY"
expiry = "2023-06-27"
newdf = df[df['SEM_CUSTOM_SYMBOL'].str.contains(strikeprice) & df['SEM_TRADING_SYMBOL'].str.contains(indice) & df['SEM_INSTRUMENT_NAME'].str.contains("OPTIDX") & df['SEM_EXPIRY_DATE'].str.contains(expiry) & df['SEM_CUSTOM_SYMBOL'].str.contains("CALL")]

# %%
newdf
# Out:
#       SEM_EXM_EXCH_ID  SEM_SEGMENT  SEM_SMST_SECURITY_ID SEM_INSTRUMENT_NAME  \
# 90172             NSE            D                 40023              OPTIDX
#
#        SEM_EXPIRY_CODE         SEM_TRADING_SYMBOL  SEM_LOT_UNITS  \
# 90172                0  FINNIFTY-Jun2023-18550-CE           40.0
#
#                 SEM_CUSTOM_SYMBOL      SEM_EXPIRY_DATE  SEM_STRIKE_PRICE  \
# 90172  FINNIFTY 27 JUN 18550 CALL  2023-06-27 14:30:00           18550.0
#
#       SEM_OPTION_TYPE  SEM_TICK_SIZE SEM_EXPIRY_FLAG
# 90172              CE            5.0               M

# %%
newdf['SEM_SMST_SECURITY_ID'].loc[newdf.index[0]]
# Out:
# 40023

# %%
################ Above Section works perfectly dont fiddle with it :)

# %%
indice = "FINNIFTY "
expiry_day = "27 "
expiry_month = "JUN "
strikeprice = "19550 "
option_type = "CALL"

option_to_buy = indice + expiry_day + expiry_month + strikeprice + option_type
print(option_to_buy)
# Out:
# FINNIFTY 27 JUN 19550 CALL

# %%
#this code will get option security id to order
optiondf = df[df['SEM_CUSTOM_SYMBOL'] == option_to_buy ]
buy_call_id = optiondf['SEM_SMST_SECURITY_ID'].loc[optiondf.index[0]]
print(buy_call_id)
# Out:
# 40071

# %%
################ Above Section is short version of above section... works perfectly dont fiddle with it :)
